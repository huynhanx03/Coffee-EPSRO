# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 0.1. Create data

# %%
begin0s = [
    "", "xin chào", "chào"
]

begin1s = [
  "", "epsro", "cửa hàng", "nhân viên", "bạn", "cậu", "em", "anh"
]

begin2s = [
  "", "cho anh hỏi", "cho em hỏi", "cho mình hỏi", "cho tớ hỏi", "cho tôi hỏi"
]

separas = [
    " ",
    # ", "
]

ends = [
    "",
    # "."
]

objects = [
    "tôi", "anh", "em", "mình", "tớ"
]

# %%
productNames = ['cà phê']

# %%
# Câu hỏi dựa trên tiêu chí:
# + Số lượng
# + Thông tin ()
# + Giá
# + Mô tả
# + Công thức

productInformationQuestions = [
    'thông tin về "sản phẩm"',

    # Số lượng
    '"sản phẩm" còn hàng không',
    'hiện tại có thể có bao nhiêu "sản phẩm"',
    # 'hiện tại có thể đặt bao nhiêu "sản phẩm"',

    # Giá tiền
    # '"sản phẩm" bao nhiêu tiền',
    '"sản phẩm" giá bao nhiêu',
    '"sản phẩm" giá như thế nào',
    # '"sản phẩm" được bán bao nhiêu',

    # Mô tả
    '"sản phẩm" được mô tả như thế nào',

    # Công thức
    '"sản phẩm" được chế biến như thế nào',
    'công thức của "sản phẩm" là gì',

    # Loại sản phẩm
    'loại sản phẩm của "sản phẩm" là gì',
]

sizeWords = [
    'kích cỡ',
    'size',
    'kích thước',
    'cỡ'
]

sizes = [
    'nhỏ',
    'vừa',
    'lớn'
]

resultInformationQuestions = []

for question in productInformationQuestions:
  for begin0 in begin0s:
    for begin1 in begin1s:
      for begin2 in begin2s:
        for separa in separas:
          for end in ends:
            for productName in productNames:

              # Về kích thước
              # if question == '"sản phẩm" còn hàng không' or question == 'hiện tại có thể có bao nhiêu "sản phẩm"' or question == 'hiện tại có thể đặt bao nhiêu "sản phẩm"':
              #   for sizeWord in sizeWords:
              #      for size in sizes:
                    # questionChange = question.replace('"sản phẩm"', productName + " với " + sizeWord + " " + size)
                    # newQuestionChange = begin0 + ("" if begin0 == "" else separa) + begin1 + ("" if begin1 == "" else separa) + begin2 + ("" if begin2 == "" else separa) + questionChange + end

                    # resultInformationQuestions.append(newQuestionChange)

                    # questionChange = question.replace('"sản phẩm"', productName + " " + sizeWord + " " + size)
                    # newQuestionChange = begin0 + ("" if begin0 == "" else separa) + begin1 + ("" if begin1 == "" else separa) + begin2 + ("" if begin2 == "" else separa) + questionChange + end

                    # resultInformationQuestions.append(newQuestionChange)

              # Thay thế tên sản phẩm
              quenstionReplace = question.replace('"sản phẩm"', productName)

              newQuestion = begin0 + ("" if begin0 == "" else separa) + begin1 + ("" if begin1 == "" else separa) + begin2 + ("" if begin2 == "" else separa) + quenstionReplace + end

              resultInformationQuestions.append(newQuestion)


resultInformationQuestions = list(set(resultInformationQuestions))

print("Số lượng dữ liệu của câu hỏi về thông tin sản phẩm:", len(resultInformationQuestions))

# Hiển thị câu hỏi
# resultInformationQuestions
# Out:
# Số lượng dữ liệu của câu hỏi về thông tin sản phẩm: 1296

# %%
productTopSellQuestions = [
    'danh sách sản phẩm bán chạy hàng đầu',
    'danh sách sản phẩm bán chạy nhất',
    'danh sách sản phẩm được mua nhiều nhất'
    'danh sách sản phẩm được mua hàng đầu',
    'danh sách sản phẩm được mọi người mua nhiều nhất',
    'danh sách sản phẩm được mọi người mua hàng đầu',
    'danh sách sản phẩm thu hút mọi người nhất',
    'danh sách sản phẩm thu hút mọi người mua nhièu nhất',
]

resultProductTopSellQuestions = []

for question in productTopSellQuestions:
  for begin0 in begin0s:
    for begin1 in begin1s:
      for begin2 in begin2s:
        for separa in separas:
          for end in ends:
            newQuestion = begin0 + ("" if begin0 == "" else separa) + begin1 + ("" if begin1 == "" else separa) + begin2 + ("" if begin2 == "" else separa) + question + end

            resultProductTopSellQuestions.append(newQuestion)

resultProductTopSellQuestions = list(set(resultProductTopSellQuestions))

print("Số lượng dữ liệu của câu hỏi về sản phẩm bán chạy:", len(resultProductTopSellQuestions))

# Hiển thị câu hỏi
# resultProductTopSellQuestions
# Out:
# Số lượng dữ liệu của câu hỏi về sản phẩm bán chạy: 1008

# %%
recommendedProductQuestions = [
    'gợi ý sản phẩm',
    'gợi ý cà phê',
    'gợi ý sản phẩm cho "object"',
    'gợi ý sản phẩm cho "object" với',
    'gợi ý sản phẩm cho "object" được không',
    'gợi ý sản phẩm cho "object" đi',
    'gợi ý cà phê tương tự cho "object" với',
    'gợi ý cà phê tương tự cho "object" được không',
    'gợi ý cà phê tương tự cho "object" đi',
    'gợi ý cho "object" cà phê tương tự với',
    'gợi ý cho "object" cà phê tương tự được không',
    'gợi ý cho "object" cà phê tương tự đi',
    'gợi ý cho "object" sản phẩm với',
    'gợi ý cho "object" sản phẩm được không',
    'gợi ý cho "object" sản phẩm đi',
    'cho "object" hỏi sản phẩm tương tự với',
    'cho "object" hỏi sản phẩm tương tự được không',
    'cho "object" hỏi sản phẩm tương tự đi',
    'cho "object" hỏi cà phê tương tự với',
    'cho "object" hỏi cà phê tương tự được không',
    'cho "object" hỏi cà phê tương tự đi',
    'sản phẩm tương tự',
    'cà phê tương tự',
]

resultRecommendedProductQuestions = []

for question in recommendedProductQuestions:
  for begin0 in begin0s:
    for begin1 in begin1s:
      for separa in separas:
        for end in ends:
          for objectSelect in objects:
            newQuestion = begin0 + ("" if begin0 == "" else separa) + begin1 + ("" if begin1 == "" else separa) + question + end

            newQuestion = newQuestion.replace('"object"', objectSelect)

            resultRecommendedProductQuestions.append(newQuestion)

resultRecommendedProductQuestions = list(set(resultRecommendedProductQuestions))

print("Số lượng dữ liệu của câu hỏi về gợi ý sản phẩm nhanh chóng:", len(resultRecommendedProductQuestions))

# Hiển thị câu hỏi
# resultRecommendedProductQuestions
# Out:
# Số lượng dữ liệu của câu hỏi về gợi ý sản phẩm nhanh chóng: 2376

# %% [markdown]
# ## Xuất file excel

# %%
import pandas as pd

sizeInformationQuestion = len(resultInformationQuestions)
sizeProductTopSellQuestion = len(resultProductTopSellQuestions)
sizeRecommendedProductQuestion = len(resultRecommendedProductQuestions)

questions = resultInformationQuestions + resultProductTopSellQuestions + resultRecommendedProductQuestions

print("Số lượng dữ liệu câu hỏi: ", len(questions))

infomations = [1] * sizeInformationQuestion + [0] * sizeProductTopSellQuestion + [0] * sizeRecommendedProductQuestion
productTopSells = [0] * sizeInformationQuestion + [1] * sizeProductTopSellQuestion + [0] * sizeRecommendedProductQuestion
recommendedProducts = [0] * sizeInformationQuestion + [0] * sizeProductTopSellQuestion + [1] * sizeRecommendedProductQuestion

# Tạo DataFrame từ dữ liệu
data = {'Question': questions,
        'infomation': infomations,
        'productTopSell': productTopSells,
        'recommendedProduct': recommendedProducts}

df = pd.DataFrame(data)
df = df.sample(frac=1).reset_index(drop=True)

import os

# Đảm bảo thư mục tồn tại trước khi ghi vào file Excel
directory = '/content/drive/MyDrive/Datatrain/coffee/'
if not os.path.exists(directory):
    os.makedirs(directory)

# Ghi DataFrame vào file Excel
df.to_csv('/content/drive/MyDrive/Datatrain/coffee/coffee.csv', index=False)

print("Xuất ra thành công!")
# Out:
# Số lượng dữ liệu câu hỏi:  4680
# Xuất ra thành công!

# %% [markdown]
# # 0.2. Data augmentation

# %%
import os

path = "/content/drive/My Drive/BERT"
os.chdir(path)
# !ls

# %%
# !pip3 install fairseq
# !pip3 install fastbpe
# !pip3 install vncorenlp
# !pip3 install transformers
# Out:
# Requirement already satisfied: fairseq in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from fairseq) (1.16.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from fairseq) (3.0.10)
# Requirement already satisfied: hydra-core<1.1,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from fairseq) (1.0.7)
# Requirement already satisfied: omegaconf<2.1 in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.0.6)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fairseq) (2024.5.15)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.4.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.3.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fairseq) (4.66.4)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.9.2)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from fairseq) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fairseq) (1.25.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.10/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq) (4.8)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq) (6.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq) (4.12.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (2.8.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (4.9.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->fairseq) (12.5.40)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->fairseq) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->fairseq) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->fairseq) (1.3.0)
# Requirement already satisfied: fastbpe in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: vncorenlp in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vncorenlp) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vncorenlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vncorenlp) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vncorenlp) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vncorenlp) (2024.6.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)

# %%
#Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter)
# !mkdir -p vncorenlp/models/wordsegmenter
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# !mv VnCoreNLP-1.1.1.jar vncorenlp/
# !mv vi-vocab vncorenlp/models/wordsegmenter/
# !mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/
# Out:
# --2024-06-19 15:25:29--  https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27412575 (26M) [application/octet-stream]
# Saving to: ‘VnCoreNLP-1.1.1.jar’
#
# VnCoreNLP-1.1.1.jar 100%[===================>]  26.14M  62.5MB/s    in 0.4s
#
# 2024-06-19 15:25:30 (62.5 MB/s) - ‘VnCoreNLP-1.1.1.jar’ saved [27412575/27412575]
#
# --2024-06-19 15:25:30--  https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 526544 (514K) [application/octet-stream]
# Saving to: ‘vi-vocab’
#
# vi-vocab            100%[===================>] 514.20K  --.-KB/s    in 0.03s
#
# 2024-06-19 15:25:30 (14.8 MB/s) - ‘vi-vocab’ saved [526544/526544]
#
# --2024-06-19 15:25:30--  https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 128508 (125K) [text/plain]
# Saving to: ‘wordsegmenter.rdr’
#
# wordsegmenter.rdr   100%[===================>] 125.50K  --.-KB/s    in 0.02s
#
# 2024-06-19 15:25:30 (6.03 MB/s) - ‘wordsegmenter.rdr’ saved [128508/128508]

# %%
# !wget https://public.vinai.io/PhoBERT_base_fairseq.tar.gz
# !tar -xzvf PhoBERT_base_fairseq.tar.gz
# Out:
# --2024-06-19 15:20:25--  https://public.vinai.io/PhoBERT_base_fairseq.tar.gz
# Resolving public.vinai.io (public.vinai.io)... 52.84.162.15, 52.84.162.17, 52.84.162.36, ...
# Connecting to public.vinai.io (public.vinai.io)|52.84.162.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1243308020 (1.2G) [application/x-tar]
# Saving to: ‘PhoBERT_base_fairseq.tar.gz’
#
# PhoBERT_base_fairse 100%[===================>]   1.16G  64.8MB/s    in 20s
#
# 2024-06-19 15:20:47 (58.0 MB/s) - ‘PhoBERT_base_fairseq.tar.gz’ saved [1243308020/1243308020]
#
# PhoBERT_base_fairseq/
# PhoBERT_base_fairseq/bpe.codes
# PhoBERT_base_fairseq/model.pt
# PhoBERT_base_fairseq/dict.txt

# %%
from fairseq.models.roberta import RobertaModel
phoBERT = RobertaModel.from_pretrained('PhoBERT_base_fairseq', checkpoint_file='model.pt')
phoBERT.eval()  # disable dropout (or leave in train mode to finetune
# Out:
# 1042301B [00:00, 21497161.50B/s]
# 456318B [00:00, 11909107.05B/s]
# RobertaHubInterface(
#   (model): RobertaModel(
#     (encoder): RobertaEncoder(
#       (sentence_encoder): TransformerEncoder(
#         (dropout_module): FairseqDropout()
#         (embed_tokens): Embedding(64001, 768, padding_idx=1)
#         (embed_positions): LearnedPositionalEmbedding(258, 768, padding_idx=1)
#         (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (layers): ModuleList(
#           (0-11): 12 x TransformerEncoderLayerBase(
#             (self_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=768, out_features=768, bias=True)
#               (v_proj): Linear(in_features=768, out_features=768, bias=True)
#               (q_proj): Linear(in_features=768, out_features=768, bias=True)
#               (out_proj): Linear(in_features=768, out_features=768, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout_module): FairseqDropout()
#             (activation_dropout_module): FairseqDropout()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (lm_head): RobertaLMHead(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (classification_heads): ModuleDict()
#   )
# )

# %%
from vncorenlp import VnCoreNLP
rdrsegmenter = VnCoreNLP("vncorenlp/VnCoreNLP-1.1.1.jar", annotators="wseg", max_heap_size='-Xmx500m')

text = 'Tôn Ngộ Không phò Đường Tăng đi thỉnh kinh tại Tây Trúc'
text_masked = 'Học sinh được  <mask> do dịch covid-19'
# Tokenize câu gốc và thay từ phò bằng <mask>
words = rdrsegmenter.tokenize(text)[0]
for i, token in enumerate(words):
  if token == 'phò':
    words[i] = ' <mask>'
text_masked_tok = ' '.join(words)
print('text_masked_tok: \n', text_masked_tok)
# Out:
# text_masked_tok:
#  Tôn_Ngộ_Không  <mask> Đường Tăng đi thỉnh_kinh tại Tây_Trúc

# %%
ques = 'cậu cho em hỏi loại sản phẩm của cà phê  <mask> là gì'

# %%
from fairseq.data.encoders.fastbpe import fastBPE
from fairseq import options
import numpy as np

# Khởi tạo Byte Pair Encoding cho PhoBERT
class BPE():
  bpe_codes = 'PhoBERT_base_fairseq/bpe.codes'
args = BPE()
phoBERT.bpe = fastBPE(args) #Incorporate the BPE encoder into PhoBERT

# Filling marks
topk_filled_outputs = phoBERT.fill_mask(ques, topk=10)
topk_probs = [item[1] for item in topk_filled_outputs]
print('Total probability: ', np.sum(topk_probs))
print('Input sequence: ', ques)
print('Top 10 in mask: ')
for i, output in enumerate(topk_filled_outputs):
  print(output[0])
# Out:
# Total probability:  0.35049183014780283
# Input sequence:  cậu cho em hỏi loại sản phẩm của cà phê <mask> là gì
# Top 10 in mask:
# cậu cho em hỏi loại sản phẩm của cà phêViệt_Nam là gì
# cậu cho em hỏi loại sản phẩm của cà phênày là gì
# cậu cho em hỏi loại sản phẩm của cà phêĐà_Lạt là gì
# cậu cho em hỏi loại sản phẩm của cà phêta là gì
# cậu cho em hỏi loại sản phẩm của cà phêViệt là gì
# cậu cho em hỏi loại sản phẩm của cà phêMỹ là gì
# cậu cho em hỏi loại sản phẩm của cà phêđen là gì
# cậu cho em hỏi loại sản phẩm của cà phêđó là gì
# cậu cho em hỏi loại sản phẩm của cà phêTrung_Quốc là gì
# cậu cho em hỏi loại sản phẩm của cà phêem là gì

# %% [markdown]
# # I. Preprocessing data

# %%
import pandas as pd

train_file = pd.read_csv('/content/coffee.csv', encoding='utf-8')

# %%
import pandas as pd

train_file = pd.read_csv('/content/drive/MyDrive/Datatrain/coffee/coffee.csv', encoding='utf-8')

# %%
train_file
# Out:
#                                                Question  infomation  \
# 0     chào cửa hàng cho tôi hỏi danh sách sản phẩm đ...           0
# 1     xin chào epsro danh sách sản phẩm thu hút mọi ...           0
# 2                 chào cho em hỏi cà phê còn hàng không           1
# 3       xin chào anh cho tôi hỏi cà phê giá như thế nào           1
# 4             chào em cho anh hỏi sản phẩm tương tự với           0
# ...                                                 ...         ...
# 4675         chào nhân viên gợi ý sản phẩm cho mình với           0
# 4676   chào nhân viên gợi ý sản phẩm cho tôi được không           0
# 4677  chào em cho mình hỏi cà phê được chế biến như ...           1
# 4678  xin chào cho tôi hỏi danh sách sản phẩm thu hú...           0
# 4679     chào nhân viên gợi ý cho em cà phê tương tự đi           0
#
#       productTopSell  recommendedProduct
# 0                  1                   0
# 1                  1                   0
# 2                  0                   0
# 3                  0                   0
# 4                  0                   1
# ...              ...                 ...
# 4675               0                   1
# 4676               0                   1
# 4677               0                   0
# 4678               1                   0
# 4679               0                   1
#
# [4680 rows x 4 columns]

# %%
train_contexts = train_file['Question'].tolist()

# %%
train_contexts
# Out:
# ['chào cửa hàng cho tôi hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào epsro danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'chào cho em hỏi cà phê còn hàng không',
#  'xin chào anh cho tôi hỏi cà phê giá như thế nào',
#  'chào em cho anh hỏi sản phẩm tương tự với',
#  'anh cho em hỏi cà phê được chế biến như thế nào',
#  'chào epsro cho em hỏi cà phê tương tự đi',
#  'epsro cho tớ hỏi cà phê được chế biến như thế nào',
#  'xin chào gợi ý cà phê tương tự cho tớ được không',
#  'chào cậu cho tôi hỏi loại sản phẩm của cà phê là gì',
#  'xin chào anh cho anh hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào anh gợi ý sản phẩm cho tớ với',
#  'xin chào bạn cho anh hỏi danh sách sản phẩm bán chạy nhất',
#  'anh danh sách sản phẩm được mọi người mua nhiều nhất',
#  'chào em gợi ý cho anh sản phẩm với',
#  'xin chào bạn gợi ý cho em cà phê tương tự với',
#  'chào epsro cho anh hỏi cà phê còn hàng không',
#  'chào cậu cho tớ hỏi sản phẩm tương tự đi',
#  'xin chào bạn cho tớ hỏi cà phê được mô tả như thế nào',
#  'xin chào cho mình hỏi cà phê giá như thế nào',
#  'bạn gợi ý cho tớ cà phê tương tự đi',
#  'nhân viên cho em hỏi cà phê tương tự đi',
#  'xin chào hiện tại có thể có bao nhiêu cà phê',
#  'bạn cho tôi hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'epsro gợi ý cho em cà phê tương tự được không',
#  'bạn cho anh hỏi cà phê giá như thế nào',
#  'anh gợi ý sản phẩm cho em với',
#  'xin chào em cho tôi hỏi danh sách sản phẩm bán chạy nhất',
#  'anh cho em hỏi cà phê tương tự với',
#  'chào em cho tớ hỏi cà phê giá như thế nào',
#  'chào cửa hàng gợi ý cà phê tương tự cho mình với',
#  'xin chào nhân viên gợi ý cho em sản phẩm với',
#  'xin chào bạn cho tớ hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào cửa hàng gợi ý cho anh cà phê tương tự được không',
#  'xin chào epsro cho tớ hỏi cà phê tương tự được không',
#  'chào em cho tôi hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'bạn cho tớ hỏi cà phê giá như thế nào',
#  'xin chào nhân viên gợi ý sản phẩm cho tớ',
#  'cậu cho anh hỏi cà phê tương tự với',
#  'gợi ý sản phẩm cho tôi',
#  'cậu cho em hỏi công thức của cà phê là gì',
#  'gợi ý cà phê tương tự cho tớ đi',
#  'em cho em hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào cho tôi hỏi sản phẩm tương tự đi',
#  'chào cho tớ hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào cửa hàng cho em hỏi công thức của cà phê là gì',
#  'nhân viên gợi ý cà phê tương tự cho anh được không',
#  'chào cậu cho tôi hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'gợi ý sản phẩm cho mình đi',
#  'xin chào bạn cho anh hỏi sản phẩm tương tự được không',
#  'chào anh gợi ý cà phê tương tự cho tớ với',
#  'chào anh gợi ý sản phẩm cho anh được không',
#  'nhân viên cho tớ hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'hiện tại có thể có bao nhiêu cà phê',
#  'chào cửa hàng cho anh hỏi sản phẩm tương tự được không',
#  'chào anh cho anh hỏi cà phê còn hàng không',
#  'bạn gợi ý sản phẩm cho mình đi',
#  'chào gợi ý cho mình cà phê tương tự được không',
#  'epsro cho mình hỏi cà phê tương tự đi',
#  'em gợi ý cho em cà phê tương tự được không',
#  'bạn gợi ý sản phẩm cho tôi',
#  'chào cậu gợi ý cho em cà phê tương tự với',
#  'xin chào cậu cho mình hỏi cà phê giá bao nhiêu',
#  'em cho em hỏi sản phẩm tương tự được không',
#  'chào cho tớ hỏi loại sản phẩm của cà phê là gì',
#  'epsro gợi ý cho tớ cà phê tương tự được không',
#  'epsro cho tôi hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'chào gợi ý cà phê tương tự cho tôi được không',
#  'cậu cho tôi hỏi công thức của cà phê là gì',
#  'cậu cà phê được chế biến như thế nào',
#  'chào cậu gợi ý cho tớ cà phê tương tự được không',
#  'cửa hàng gợi ý cà phê tương tự cho tôi đi',
#  'bạn cho tớ hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'bạn gợi ý cho mình cà phê tương tự với',
#  'chào gợi ý sản phẩm cho anh',
#  'xin chào nhân viên cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'cho tớ hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào epsro cho tôi hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'nhân viên cho em hỏi sản phẩm tương tự với',
#  'chào epsro cho tớ hỏi hiện tại có thể có bao nhiêu cà phê',
#  'cửa hàng gợi ý sản phẩm cho em',
#  'xin chào anh cho anh hỏi cà phê giá bao nhiêu',
#  'xin chào cậu cho tôi hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'chào cửa hàng gợi ý cà phê tương tự cho mình được không',
#  'bạn cho anh hỏi loại sản phẩm của cà phê là gì',
#  'xin chào cửa hàng cho em hỏi cà phê giá bao nhiêu',
#  'anh gợi ý cho tớ cà phê tương tự với',
#  'chào bạn cho mình hỏi sản phẩm tương tự được không',
#  'chào bạn cho mình hỏi cà phê tương tự được không',
#  'chào nhân viên cho tớ hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'xin chào anh cho mình hỏi cà phê tương tự được không',
#  'xin chào cho mình hỏi sản phẩm tương tự đi',
#  'xin chào bạn cho tôi hỏi sản phẩm tương tự đi',
#  'cho em hỏi sản phẩm tương tự đi',
#  'chào cậu cho tôi hỏi sản phẩm tương tự đi',
#  'xin chào cậu cho anh hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào bạn cho em hỏi cà phê tương tự đi',
#  'xin chào anh gợi ý cà phê',
#  'xin chào nhân viên cho tớ hỏi cà phê tương tự đi',
#  'xin chào cửa hàng gợi ý sản phẩm cho anh được không',
#  'chào em gợi ý cho mình sản phẩm được không',
#  'xin chào nhân viên gợi ý cho tớ sản phẩm với',
#  'xin chào nhân viên cho tớ hỏi hiện tại có thể có bao nhiêu cà phê',
#  'cửa hàng cho anh hỏi cà phê tương tự với',
#  'em gợi ý sản phẩm cho tôi',
#  'xin chào cho tôi hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào em gợi ý cho tôi sản phẩm với',
#  'chào cậu cho em hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào nhân viên gợi ý cà phê tương tự cho tớ được không',
#  'chào em cho anh hỏi cà phê được mô tả như thế nào',
#  'chào nhân viên cho mình hỏi cà phê được chế biến như thế nào',
#  'nhân viên danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'cậu gợi ý cho em cà phê tương tự được không',
#  'chào epsro gợi ý cho em sản phẩm đi',
#  'chào bạn cho tớ hỏi cà phê giá như thế nào',
#  'cửa hàng cho mình hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'chào thông tin về cà phê',
#  'xin chào bạn gợi ý sản phẩm cho tớ được không',
#  'xin chào bạn gợi ý cà phê tương tự cho tôi với',
#  'xin chào nhân viên cho tớ hỏi cà phê giá như thế nào',
#  'chào cửa hàng cho em hỏi công thức của cà phê là gì',
#  'xin chào cậu gợi ý cà phê tương tự cho mình đi',
#  'xin chào cho em hỏi cà phê tương tự được không',
#  'xin chào cho tớ hỏi cà phê giá bao nhiêu',
#  'xin chào nhân viên cho tôi hỏi thông tin về cà phê',
#  'chào epsro gợi ý cà phê tương tự cho anh đi',
#  'gợi ý cho tôi sản phẩm được không',
#  'nhân viên cho anh hỏi thông tin về cà phê',
#  'xin chào cửa hàng danh sách sản phẩm bán chạy nhất',
#  'chào nhân viên cho tôi hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào epsro cho mình hỏi cà phê giá bao nhiêu',
#  'chào anh gợi ý cho tớ cà phê tương tự với',
#  'em cho tôi hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào gợi ý cho mình cà phê tương tự với',
#  'cậu gợi ý cho tôi cà phê tương tự được không',
#  'xin chào epsro gợi ý cà phê tương tự cho anh với',
#  'chào cậu cho mình hỏi cà phê tương tự với',
#  'nhân viên cho mình hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'cửa hàng cho anh hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào cho tôi hỏi cà phê tương tự được không',
#  'chào cậu cho tôi hỏi cà phê được chế biến như thế nào',
#  'xin chào anh gợi ý sản phẩm cho tôi',
#  'chào bạn cho tớ hỏi sản phẩm tương tự được không',
#  'chào epsro gợi ý sản phẩm cho anh với',
#  'chào gợi ý cà phê tương tự cho tớ với',
#  'nhân viên cho tôi hỏi cà phê tương tự đi',
#  'chào anh cho anh hỏi thông tin về cà phê',
#  'bạn gợi ý cho anh cà phê tương tự được không',
#  'epsro gợi ý cà phê tương tự cho tôi đi',
#  'bạn danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'chào em cho mình hỏi cà phê tương tự với',
#  'chào cửa hàng cho tôi hỏi công thức của cà phê là gì',
#  'xin chào anh cho em hỏi cà phê giá như thế nào',
#  'xin chào em cho tớ hỏi cà phê tương tự đi',
#  'chào anh cho mình hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào cửa hàng gợi ý cho em sản phẩm được không',
#  'cửa hàng cho tớ hỏi cà phê được mô tả như thế nào',
#  'xin chào gợi ý cho tôi cà phê tương tự đi',
#  'chào anh gợi ý cho mình sản phẩm được không',
#  'chào cậu cho anh hỏi cà phê được mô tả như thế nào',
#  'chào em cho mình hỏi cà phê còn hàng không',
#  'chào anh danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào anh gợi ý cà phê tương tự cho tôi đi',
#  'em cho anh hỏi cà phê tương tự đi',
#  'em gợi ý cho tôi cà phê tương tự được không',
#  'chào em cho anh hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào epsro gợi ý cho em sản phẩm đi',
#  'chào cửa hàng cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào cửa hàng cà phê còn hàng không',
#  'xin chào nhân viên gợi ý sản phẩm cho tôi',
#  'cửa hàng cho mình hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'em danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'cho em hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào nhân viên gợi ý cà phê tương tự cho anh được không',
#  'chào nhân viên danh sách sản phẩm thu hút mọi người nhất',
#  'chào anh danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào cậu cho mình hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'chào bạn cho anh hỏi cà phê tương tự đi',
#  'xin chào nhân viên cho em hỏi cà phê còn hàng không',
#  'chào em cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'chào em danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào cửa hàng gợi ý cho tôi sản phẩm đi',
#  'cậu cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'chào nhân viên gợi ý cho mình cà phê tương tự được không',
#  'xin chào bạn cho mình hỏi danh sách sản phẩm bán chạy nhất',
#  'bạn cho em hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào em cho tôi hỏi sản phẩm tương tự với',
#  'cửa hàng loại sản phẩm của cà phê là gì',
#  'xin chào em cho mình hỏi cà phê tương tự đi',
#  'chào cậu cho em hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào cửa hàng danh sách sản phẩm bán chạy hàng đầu',
#  'xin chào nhân viên gợi ý sản phẩm cho tớ được không',
#  'chào anh cho tớ hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'cho anh hỏi công thức của cà phê là gì',
#  'xin chào epsro cho em hỏi cà phê được mô tả như thế nào',
#  'xin chào em cho tớ hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'cậu danh sách sản phẩm bán chạy hàng đầu',
#  'chào anh gợi ý sản phẩm cho tôi',
#  'chào epsro cho tớ hỏi cà phê giá bao nhiêu',
#  'chào anh cà phê tương tự',
#  'chào cho tớ hỏi sản phẩm tương tự với',
#  'chào cho anh hỏi cà phê còn hàng không',
#  'xin chào gợi ý cho mình sản phẩm với',
#  'xin chào cho tớ hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'xin chào nhân viên gợi ý cho tôi sản phẩm được không',
#  'cửa hàng gợi ý cà phê tương tự cho em với',
#  'xin chào cho mình hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'anh danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'cửa hàng danh sách sản phẩm bán chạy nhất',
#  'chào gợi ý cho tôi sản phẩm được không',
#  'chào cửa hàng cho tớ hỏi cà phê còn hàng không',
#  'chào cửa hàng gợi ý sản phẩm cho anh với',
#  'xin chào nhân viên gợi ý cho anh sản phẩm đi',
#  'chào cửa hàng cho em hỏi cà phê giá bao nhiêu',
#  'xin chào cho tớ hỏi thông tin về cà phê',
#  'xin chào bạn cho em hỏi cà phê tương tự được không',
#  'xin chào cậu cho tôi hỏi cà phê tương tự được không',
#  'em hiện tại có thể có bao nhiêu cà phê',
#  'xin chào em cho tôi hỏi thông tin về cà phê',
#  'xin chào cậu loại sản phẩm của cà phê là gì',
#  'xin chào cửa hàng gợi ý sản phẩm cho tôi được không',
#  'chào em cho mình hỏi cà phê được mô tả như thế nào',
#  'cửa hàng gợi ý cho tôi sản phẩm với',
#  'chào cửa hàng cho anh hỏi loại sản phẩm của cà phê là gì',
#  'nhân viên cho anh hỏi cà phê tương tự với',
#  'xin chào cậu cho tôi hỏi cà phê được mô tả như thế nào',
#  'chào cửa hàng cho mình hỏi cà phê được chế biến như thế nào',
#  'cửa hàng cho anh hỏi hiện tại có thể có bao nhiêu cà phê',
#  'nhân viên danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào nhân viên gợi ý cho tớ cà phê tương tự với',
#  'bạn cho tôi hỏi danh sách sản phẩm bán chạy nhất',
#  'xin chào anh cho tớ hỏi cà phê được mô tả như thế nào',
#  'xin chào anh cho em hỏi công thức của cà phê là gì',
#  'chào cửa hàng cho anh hỏi sản phẩm tương tự với',
#  'chào em gợi ý cà phê tương tự cho mình được không',
#  'xin chào cho mình hỏi thông tin về cà phê',
#  'chào epsro cho tôi hỏi sản phẩm tương tự đi',
#  'anh cho mình hỏi loại sản phẩm của cà phê là gì',
#  'chào bạn công thức của cà phê là gì',
#  'em cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào bạn cho em hỏi sản phẩm tương tự được không',
#  'xin chào bạn gợi ý cà phê tương tự cho anh được không',
#  'chào anh danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'nhân viên gợi ý sản phẩm cho mình với',
#  'xin chào cậu cho anh hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào nhân viên cà phê được mô tả như thế nào',
#  'chào anh cho tớ hỏi sản phẩm tương tự được không',
#  'xin chào anh cà phê giá bao nhiêu',
#  'chào bạn gợi ý sản phẩm cho anh',
#  'epsro cho anh hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'chào bạn cho em hỏi cà phê tương tự với',
#  'cậu cho anh hỏi cà phê được chế biến như thế nào',
#  'xin chào cậu gợi ý sản phẩm cho tôi',
#  'xin chào bạn cho mình hỏi thông tin về cà phê',
#  'chào cửa hàng gợi ý cà phê tương tự cho tôi với',
#  'xin chào cậu danh sách sản phẩm bán chạy hàng đầu',
#  'chào nhân viên cho anh hỏi loại sản phẩm của cà phê là gì',
#  'xin chào cậu cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'chào bạn gợi ý sản phẩm cho tớ đi',
#  'chào bạn cho mình hỏi sản phẩm tương tự với',
#  'chào epsro gợi ý sản phẩm cho tôi được không',
#  'chào cho anh hỏi sản phẩm tương tự được không',
#  'chào cậu gợi ý cà phê tương tự cho tôi đi',
#  'em gợi ý cho tớ sản phẩm được không',
#  'cho mình hỏi cà phê tương tự với',
#  'chào em cho anh hỏi cà phê giá như thế nào',
#  'xin chào gợi ý cà phê tương tự cho mình với',
#  'chào anh cho tớ hỏi cà phê được mô tả như thế nào',
#  'chào nhân viên cho tớ hỏi cà phê được chế biến như thế nào',
#  'chào gợi ý sản phẩm cho anh được không',
#  'chào cửa hàng loại sản phẩm của cà phê là gì',
#  'chào cửa hàng gợi ý sản phẩm cho mình với',
#  'xin chào nhân viên cho anh hỏi thông tin về cà phê',
#  'chào cậu cho anh hỏi cà phê được chế biến như thế nào',
#  'xin chào bạn gợi ý cà phê tương tự cho em được không',
#  'chào nhân viên cho anh hỏi hiện tại có thể có bao nhiêu cà phê',
#  'cậu gợi ý cà phê tương tự cho em với',
#  'chào nhân viên gợi ý cho anh sản phẩm với',
#  'cửa hàng cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào cho tớ hỏi cà phê tương tự với',
#  'xin chào gợi ý cà phê tương tự cho tôi được không',
#  'xin chào cho em hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào epsro danh sách sản phẩm thu hút mọi người nhất',
#  'chào anh cho mình hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'xin chào em danh sách sản phẩm bán chạy nhất',
#  'chào anh cho mình hỏi cà phê tương tự đi',
#  'xin chào em cà phê giá bao nhiêu',
#  'epsro gợi ý cà phê',
#  'epsro cho mình hỏi loại sản phẩm của cà phê là gì',
#  'xin chào anh gợi ý sản phẩm cho em được không',
#  'xin chào cậu gợi ý cho em cà phê tương tự đi',
#  'xin chào cửa hàng gợi ý cà phê tương tự cho tôi được không',
#  'gợi ý cho tớ sản phẩm được không',
#  'cậu cho tớ hỏi sản phẩm tương tự đi',
#  'em gợi ý cho tôi sản phẩm đi',
#  'chào cửa hàng cho tớ hỏi công thức của cà phê là gì',
#  'em cho tôi hỏi sản phẩm tương tự với',
#  'epsro gợi ý cho tớ sản phẩm với',
#  'chào cửa hàng cho anh hỏi hiện tại có thể có bao nhiêu cà phê',
#  'chào anh gợi ý cà phê tương tự cho tôi được không',
#  'chào nhân viên cho tớ hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào em cho tớ hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'em gợi ý cho em sản phẩm với',
#  'chào gợi ý cà phê tương tự cho anh đi',
#  'nhân viên cho anh hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'em gợi ý cho tớ cà phê tương tự đi',
#  'xin chào anh gợi ý cho anh sản phẩm với',
#  'anh cà phê tương tự',
#  'bạn cho tôi hỏi cà phê được mô tả như thế nào',
#  'cậu cho em hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'chào epsro cho tớ hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'cửa hàng gợi ý cà phê tương tự cho tớ được không',
#  'xin chào bạn cho tôi hỏi công thức của cà phê là gì',
#  'xin chào anh cho mình hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'epsro cho tớ hỏi cà phê tương tự đi',
#  'xin chào bạn gợi ý cho anh cà phê tương tự đi',
#  'em gợi ý cà phê tương tự cho tôi đi',
#  'xin chào anh gợi ý cho mình cà phê tương tự được không',
#  'chào em cho em hỏi cà phê giá như thế nào',
#  'chào nhân viên gợi ý sản phẩm cho anh đi',
#  'xin chào cho tôi hỏi sản phẩm tương tự với',
#  'xin chào epsro công thức của cà phê là gì',
#  'chào epsro gợi ý sản phẩm cho tớ đi',
#  'chào epsro gợi ý cho tôi sản phẩm đi',
#  'bạn gợi ý cho tôi cà phê tương tự được không',
#  'chào epsro cho em hỏi cà phê được mô tả như thế nào',
#  'nhân viên cho anh hỏi cà phê còn hàng không',
#  'epsro cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào cậu gợi ý sản phẩm cho tớ',
#  'chào cho tôi hỏi loại sản phẩm của cà phê là gì',
#  'xin chào nhân viên cho mình hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'epsro gợi ý cho tôi cà phê tương tự đi',
#  'chào em cho tôi hỏi danh sách sản phẩm bán chạy nhất',
#  'gợi ý sản phẩm cho mình',
#  'chào nhân viên gợi ý cho tớ cà phê tương tự với',
#  'cửa hàng cho mình hỏi công thức của cà phê là gì',
#  'chào cậu hiện tại có thể có bao nhiêu cà phê',
#  'xin chào cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'chào em cho mình hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào cậu gợi ý cà phê tương tự cho mình được không',
#  'chào epsro cho mình hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'anh cho tôi hỏi cà phê giá như thế nào',
#  'chào bạn cho mình hỏi thông tin về cà phê',
#  'cho em hỏi cà phê tương tự được không',
#  'chào cho tớ hỏi cà phê tương tự đi',
#  'em cho em hỏi cà phê tương tự với',
#  'xin chào cho em hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'epsro cho tôi hỏi cà phê giá bao nhiêu',
#  'chào bạn cho em hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào anh cho mình hỏi thông tin về cà phê',
#  'xin chào anh cho em hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào cửa hàng cho anh hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'chào em cho tớ hỏi danh sách sản phẩm bán chạy nhất',
#  'chào nhân viên gợi ý cho anh cà phê tương tự đi',
#  'gợi ý cho tôi cà phê tương tự đi',
#  'xin chào cửa hàng cho em hỏi cà phê tương tự với',
#  'cho tớ hỏi cà phê còn hàng không',
#  'chào epsro gợi ý sản phẩm cho anh đi',
#  'anh cho mình hỏi sản phẩm tương tự được không',
#  'chào cậu cho tớ hỏi cà phê tương tự đi',
#  'xin chào anh cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'cậu cho anh hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào em gợi ý cho tớ sản phẩm được không',
#  'chào epsro danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào bạn cho em hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'anh cho anh hỏi cà phê giá bao nhiêu',
#  'chào cửa hàng gợi ý cà phê tương tự cho em đi',
#  'xin chào gợi ý cho em sản phẩm được không',
#  'chào cho anh hỏi danh sách sản phẩm bán chạy nhất',
#  'cậu cho anh hỏi loại sản phẩm của cà phê là gì',
#  'nhân viên cho anh hỏi cà phê được chế biến như thế nào',
#  'chào cửa hàng gợi ý sản phẩm cho tớ',
#  'xin chào epsro cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'bạn gợi ý cà phê tương tự cho em đi',
#  'chào em gợi ý cho tớ cà phê tương tự đi',
#  'xin chào anh cho anh hỏi cà phê còn hàng không',
#  'xin chào epsro cho tớ hỏi thông tin về cà phê',
#  'xin chào cậu cho tớ hỏi cà phê được mô tả như thế nào',
#  'chào cửa hàng cho anh hỏi cà phê giá bao nhiêu',
#  'chào gợi ý cà phê tương tự cho tôi đi',
#  'xin chào anh gợi ý cà phê tương tự cho em được không',
#  'chào cho mình hỏi cà phê giá bao nhiêu',
#  'em cho mình hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào epsro cho em hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'cậu cho tớ hỏi cà phê giá bao nhiêu',
#  'xin chào nhân viên cho em hỏi sản phẩm tương tự đi',
#  'xin chào nhân viên gợi ý sản phẩm cho mình với',
#  'cửa hàng cho tôi hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào cửa hàng gợi ý cà phê tương tự cho tớ với',
#  'chào cậu gợi ý cà phê tương tự cho tớ được không',
#  'xin chào anh cho tôi hỏi sản phẩm tương tự đi',
#  'chào cửa hàng cà phê giá bao nhiêu',
#  'xin chào bạn cho tớ hỏi cà phê giá như thế nào',
#  'xin chào bạn cà phê được mô tả như thế nào',
#  'cửa hàng cho mình hỏi sản phẩm tương tự được không',
#  'chào gợi ý cho mình sản phẩm được không',
#  'xin chào cửa hàng gợi ý cho mình cà phê tương tự với',
#  'chào cửa hàng gợi ý cà phê tương tự cho tôi được không',
#  'chào nhân viên cho anh hỏi cà phê tương tự với',
#  'xin chào bạn cho tớ hỏi danh sách sản phẩm bán chạy nhất',
#  'nhân viên cho tớ hỏi cà phê được chế biến như thế nào',
#  'xin chào cậu cho anh hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào anh gợi ý cà phê tương tự cho em đi',
#  'nhân viên cho tôi hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'epsro cho em hỏi thông tin về cà phê',
#  'anh cho anh hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'epsro cho anh hỏi cà phê tương tự được không',
#  'bạn gợi ý cà phê tương tự cho anh với',
#  'bạn cho mình hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào cho mình hỏi cà phê còn hàng không',
#  'chào anh cho tôi hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào nhân viên cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào cậu cho tôi hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào cửa hàng cho anh hỏi cà phê còn hàng không',
#  'xin chào cậu cho anh hỏi loại sản phẩm của cà phê là gì',
#  'chào epsro cho tớ hỏi cà phê được chế biến như thế nào',
#  'xin chào anh cho tớ hỏi sản phẩm tương tự đi',
#  'chào nhân viên cho em hỏi công thức của cà phê là gì',
#  'cậu cho mình hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào epsro cà phê được chế biến như thế nào',
#  'chào em cho em hỏi cà phê tương tự đi',
#  'chào bạn gợi ý cho anh cà phê tương tự với',
#  'xin chào nhân viên cho mình hỏi cà phê tương tự được không',
#  'xin chào cửa hàng cho anh hỏi sản phẩm tương tự được không',
#  'cậu hiện tại có thể có bao nhiêu cà phê',
#  'chào bạn thông tin về cà phê',
#  'chào cậu cho anh hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào epsro hiện tại có thể có bao nhiêu cà phê',
#  'em gợi ý sản phẩm cho anh với',
#  'cửa hàng cho em hỏi sản phẩm tương tự với',
#  'chào cậu gợi ý cà phê tương tự cho em được không',
#  'chào em cho tôi hỏi loại sản phẩm của cà phê là gì',
#  'xin chào cửa hàng gợi ý cà phê tương tự cho em được không',
#  'xin chào cho anh hỏi cà phê tương tự đi',
#  'anh cho tớ hỏi cà phê tương tự được không',
#  'chào cửa hàng gợi ý cà phê',
#  'chào em cà phê giá bao nhiêu',
#  'cho em hỏi cà phê giá như thế nào',
#  'xin chào epsro cho anh hỏi cà phê được mô tả như thế nào',
#  'chào nhân viên cho em hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào cậu hiện tại có thể có bao nhiêu cà phê',
#  'cửa hàng cho em hỏi loại sản phẩm của cà phê là gì',
#  'cậu gợi ý sản phẩm cho em được không',
#  'nhân viên gợi ý sản phẩm cho tôi đi',
#  'cửa hàng cho mình hỏi cà phê tương tự đi',
#  'chào nhân viên sản phẩm tương tự',
#  'xin chào bạn cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'xin chào epsro cho em hỏi cà phê giá bao nhiêu',
#  'xin chào em gợi ý cà phê tương tự cho tớ được không',
#  'chào anh cho em hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'cậu cho anh hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'nhân viên gợi ý cho tớ cà phê tương tự được không',
#  'chào cửa hàng gợi ý cho anh sản phẩm với',
#  'xin chào anh cà phê tương tự',
#  'chào em cho tớ hỏi cà phê được mô tả như thế nào',
#  'xin chào cho tôi hỏi thông tin về cà phê',
#  'nhân viên cho em hỏi cà phê tương tự được không',
#  'chào bạn gợi ý cà phê tương tự cho anh với',
#  'chào cho tôi hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào cho anh hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào bạn cho tớ hỏi cà phê tương tự được không',
#  'chào cho mình hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'anh gợi ý sản phẩm cho tôi đi',
#  'chào nhân viên cho tớ hỏi cà phê tương tự đi',
#  'chào bạn gợi ý cho tớ sản phẩm với',
#  'bạn cho tôi hỏi sản phẩm tương tự được không',
#  'em cho anh hỏi cà phê được mô tả như thế nào',
#  'chào nhân viên cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'bạn cho mình hỏi cà phê giá như thế nào',
#  'epsro cho tớ hỏi cà phê tương tự được không',
#  'bạn gợi ý cà phê tương tự cho anh được không',
#  'cửa hàng cà phê giá bao nhiêu',
#  'xin chào nhân viên cho em hỏi cà phê tương tự đi',
#  'epsro gợi ý sản phẩm cho tôi với',
#  'chào anh gợi ý cho mình cà phê tương tự với',
#  'em cho tôi hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'epsro gợi ý sản phẩm cho em',
#  'gợi ý cho anh sản phẩm đi',
#  'xin chào cho em hỏi cà phê giá như thế nào',
#  'xin chào bạn gợi ý cho anh cà phê tương tự được không',
#  'xin chào anh gợi ý cho em sản phẩm đi',
#  'chào cho mình hỏi cà phê được mô tả như thế nào',
#  'nhân viên cho mình hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào em cho tôi hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'cà phê giá như thế nào',
#  'chào cho tôi hỏi danh sách sản phẩm bán chạy nhất',
#  'chào anh cho mình hỏi loại sản phẩm của cà phê là gì',
#  'anh cho tớ hỏi cà phê giá như thế nào',
#  'chào cậu gợi ý sản phẩm cho anh đi',
#  'xin chào cậu cho mình hỏi công thức của cà phê là gì',
#  'xin chào anh gợi ý cà phê tương tự cho tớ với',
#  'xin chào cậu gợi ý cà phê tương tự cho tớ đi',
#  'nhân viên cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'chào nhân viên cho tớ hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'cho em hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'chào epsro cho mình hỏi cà phê giá như thế nào',
#  'chào cậu gợi ý cà phê tương tự cho em đi',
#  'xin chào cửa hàng gợi ý cho tớ sản phẩm được không',
#  'xin chào cửa hàng cho tớ hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'chào bạn cho anh hỏi danh sách sản phẩm bán chạy nhất',
#  'chào bạn sản phẩm tương tự',
#  'chào bạn cho anh hỏi sản phẩm tương tự đi',
#  'xin chào em gợi ý cà phê tương tự cho em đi',
#  'xin chào nhân viên cho anh hỏi loại sản phẩm của cà phê là gì',
#  'xin chào bạn cho mình hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'epsro cho anh hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào epsro cho mình hỏi sản phẩm tương tự đi',
#  'cửa hàng cho em hỏi thông tin về cà phê',
#  'chào em gợi ý cho mình cà phê tương tự với',
#  'chào cậu cho mình hỏi loại sản phẩm của cà phê là gì',
#  'epsro gợi ý cà phê tương tự cho em với',
#  'chào epsro gợi ý sản phẩm cho mình được không',
#  'chào bạn gợi ý cho anh cà phê tương tự đi',
#  'xin chào cậu gợi ý cho mình cà phê tương tự được không',
#  'xin chào anh loại sản phẩm của cà phê là gì',
#  'epsro cho tôi hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'epsro cho tôi hỏi thông tin về cà phê',
#  'em cho anh hỏi sản phẩm tương tự được không',
#  'nhân viên gợi ý sản phẩm cho tớ được không',
#  'xin chào nhân viên cho em hỏi hiện tại có thể có bao nhiêu cà phê',
#  'cho em hỏi cà phê giá bao nhiêu',
#  'xin chào cửa hàng cho tôi hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào cửa hàng cho anh hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào gợi ý sản phẩm cho tớ với',
#  'chào công thức của cà phê là gì',
#  'cậu danh sách sản phẩm bán chạy nhất',
#  'gợi ý cho em sản phẩm được không',
#  'chào epsro gợi ý cho tớ cà phê tương tự được không',
#  'nhân viên cho mình hỏi cà phê được chế biến như thế nào',
#  'xin chào epsro cho tớ hỏi cà phê còn hàng không',
#  'nhân viên cho em hỏi cà phê giá bao nhiêu',
#  'epsro gợi ý cà phê tương tự cho anh được không',
#  'cậu cho tớ hỏi sản phẩm tương tự được không',
#  'chào anh gợi ý cho anh sản phẩm đi',
#  'chào gợi ý sản phẩm cho anh đi',
#  'chào gợi ý cho anh cà phê tương tự với',
#  'xin chào bạn cho anh hỏi cà phê tương tự với',
#  'chào gợi ý cho tôi cà phê tương tự với',
#  'xin chào anh cho mình hỏi cà phê được mô tả như thế nào',
#  'cậu gợi ý cho tớ sản phẩm được không',
#  'chào bạn gợi ý cho tôi sản phẩm với',
#  'em cho anh hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'epsro loại sản phẩm của cà phê là gì',
#  'xin chào epsro gợi ý sản phẩm cho tớ được không',
#  'cho mình hỏi danh sách sản phẩm bán chạy nhất',
#  'cửa hàng cho mình hỏi sản phẩm tương tự đi',
#  'chào cửa hàng cho tớ hỏi loại sản phẩm của cà phê là gì',
#  'em gợi ý cho anh sản phẩm được không',
#  'chào cậu cho tớ hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào anh cho anh hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào anh cho tôi hỏi cà phê tương tự với',
#  'cửa hàng gợi ý cà phê tương tự cho anh với',
#  'chào bạn cà phê còn hàng không',
#  'xin chào cửa hàng gợi ý sản phẩm cho tớ với',
#  'xin chào nhân viên cho mình hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào cửa hàng cho tớ hỏi cà phê được mô tả như thế nào',
#  'chào cửa hàng cho em hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'chào anh cho tớ hỏi cà phê tương tự được không',
#  'xin chào nhân viên cho anh hỏi công thức của cà phê là gì',
#  'cửa hàng gợi ý sản phẩm',
#  'xin chào cửa hàng cho tớ hỏi cà phê tương tự được không',
#  'xin chào gợi ý cho tôi sản phẩm với',
#  'xin chào cửa hàng cho anh hỏi cà phê giá bao nhiêu',
#  'chào bạn gợi ý cho anh cà phê tương tự được không',
#  'em cho tôi hỏi cà phê giá bao nhiêu',
#  'chào cửa hàng cho tôi hỏi cà phê giá như thế nào',
#  'cho anh hỏi cà phê được mô tả như thế nào',
#  'anh cho em hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào gợi ý cho tớ cà phê tương tự với',
#  'em cho em hỏi cà phê tương tự được không',
#  'xin chào bạn gợi ý cà phê tương tự cho mình được không',
#  'chào nhân viên gợi ý sản phẩm cho em đi',
#  'chào cho em hỏi thông tin về cà phê',
#  'gợi ý cho tôi cà phê tương tự được không',
#  'bạn cho em hỏi cà phê được mô tả như thế nào',
#  'cậu cho em hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào epsro gợi ý cho anh sản phẩm đi',
#  'anh cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'cho tôi hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào nhân viên cà phê còn hàng không',
#  'chào nhân viên cho mình hỏi loại sản phẩm của cà phê là gì',
#  'xin chào cậu gợi ý cho tớ cà phê tương tự đi',
#  'chào cửa hàng cho anh hỏi cà phê được mô tả như thế nào',
#  'cậu cho tôi hỏi sản phẩm tương tự với',
#  'xin chào epsro cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'chào epsro cho tớ hỏi sản phẩm tương tự đi',
#  'chào epsro gợi ý cho anh cà phê tương tự đi',
#  'nhân viên gợi ý sản phẩm cho anh đi',
#  'xin chào nhân viên cho anh hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'chào em cà phê còn hàng không',
#  'xin chào cửa hàng cho tôi hỏi thông tin về cà phê',
#  'chào nhân viên cho anh hỏi cà phê còn hàng không',
#  'bạn cho tớ hỏi cà phê được mô tả như thế nào',
#  'xin chào bạn cho mình hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào bạn cho anh hỏi công thức của cà phê là gì',
#  'gợi ý cho em sản phẩm đi',
#  'chào gợi ý cà phê tương tự cho tớ được không',
#  'xin chào epsro gợi ý cà phê tương tự cho tớ với',
#  'chào anh gợi ý cho em sản phẩm đi',
#  'em gợi ý cà phê tương tự cho tớ được không',
#  'gợi ý sản phẩm cho em đi',
#  'em cho tôi hỏi thông tin về cà phê',
#  'bạn cho anh hỏi sản phẩm tương tự với',
#  'cậu cho tôi hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'nhân viên cho mình hỏi cà phê giá như thế nào',
#  'chào nhân viên gợi ý cà phê tương tự cho em được không',
#  'chào epsro danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào cửa hàng cho anh hỏi cà phê giá như thế nào',
#  'xin chào bạn gợi ý cho anh sản phẩm đi',
#  'chào em cho em hỏi cà phê được chế biến như thế nào',
#  'xin chào bạn gợi ý sản phẩm cho em được không',
#  'chào nhân viên gợi ý cho anh sản phẩm được không',
#  'chào em cho em hỏi loại sản phẩm của cà phê là gì',
#  'chào nhân viên công thức của cà phê là gì',
#  'chào bạn cà phê được mô tả như thế nào',
#  'xin chào bạn cà phê được chế biến như thế nào',
#  'chào bạn cho em hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'epsro cho tôi hỏi công thức của cà phê là gì',
#  'cửa hàng gợi ý sản phẩm cho mình với',
#  'cho anh hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào nhân viên gợi ý cho tôi cà phê tương tự với',
#  'chào gợi ý cho tớ sản phẩm với',
#  'xin chào bạn gợi ý cho em sản phẩm được không',
#  'xin chào cậu cho em hỏi sản phẩm tương tự với',
#  'cho tôi hỏi sản phẩm tương tự với',
#  'epsro cho em hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào cửa hàng gợi ý sản phẩm cho tôi',
#  'cậu cho anh hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào nhân viên gợi ý cà phê tương tự cho anh đi',
#  'chào em cho tớ hỏi cà phê giá bao nhiêu',
#  'cậu cho tớ hỏi cà phê tương tự với',
#  'anh cho tôi hỏi cà phê được mô tả như thế nào',
#  'bạn cho tớ hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'anh gợi ý sản phẩm cho tớ với',
#  'nhân viên gợi ý cho mình sản phẩm với',
#  'chào gợi ý cà phê tương tự cho mình đi',
#  'nhân viên cho em hỏi cà phê được mô tả như thế nào',
#  'chào nhân viên danh sách sản phẩm bán chạy hàng đầu',
#  'chào em cho em hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào anh cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào cho tôi hỏi cà phê được chế biến như thế nào',
#  'chào cửa hàng cho tớ hỏi cà phê tương tự đi',
#  'xin chào cậu cho mình hỏi cà phê còn hàng không',
#  'xin chào bạn cho tớ hỏi sản phẩm tương tự đi',
#  'xin chào anh cho em hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'xin chào em cho tôi hỏi cà phê tương tự được không',
#  'cửa hàng cho anh hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'bạn gợi ý cho anh sản phẩm với',
#  'xin chào epsro gợi ý sản phẩm cho em',
#  'nhân viên cho tôi hỏi danh sách sản phẩm bán chạy nhất',
#  'chào cửa hàng gợi ý cho tớ sản phẩm đi',
#  'xin chào epsro cho tớ hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào cửa hàng cho em hỏi sản phẩm tương tự đi',
#  'xin chào nhân viên gợi ý sản phẩm cho anh đi',
#  'em gợi ý cho tôi cà phê tương tự với',
#  'cửa hàng cho anh hỏi loại sản phẩm của cà phê là gì',
#  'chào anh gợi ý cà phê tương tự cho tớ được không',
#  'xin chào bạn gợi ý cho em sản phẩm đi',
#  'xin chào cậu cho anh hỏi sản phẩm tương tự với',
#  'xin chào nhân viên gợi ý cho anh cà phê tương tự đi',
#  'xin chào nhân viên cho mình hỏi cà phê giá bao nhiêu',
#  'chào nhân viên cho tớ hỏi cà phê giá như thế nào',
#  'em cho tớ hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'chào cửa hàng cho em hỏi sản phẩm tương tự đi',
#  'em cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'chào bạn cho mình hỏi cà phê tương tự đi',
#  'xin chào anh cho mình hỏi cà phê giá như thế nào',
#  'bạn cho tớ hỏi cà phê giá bao nhiêu',
#  'xin chào bạn cho tôi hỏi cà phê tương tự với',
#  'chào bạn danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào cửa hàng cho anh hỏi cà phê còn hàng không',
#  'chào cậu cho anh hỏi loại sản phẩm của cà phê là gì',
#  'cậu cho mình hỏi cà phê tương tự được không',
#  'anh cho anh hỏi cà phê còn hàng không',
#  'xin chào anh cho tớ hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào anh danh sách sản phẩm bán chạy nhất',
#  'chào bạn gợi ý cho em sản phẩm đi',
#  'chào anh cho em hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào bạn cho tôi hỏi cà phê được mô tả như thế nào',
#  'cho tôi hỏi cà phê được mô tả như thế nào',
#  'chào em cho anh hỏi sản phẩm tương tự đi',
#  'cửa hàng cho tôi hỏi sản phẩm tương tự với',
#  'em cho em hỏi sản phẩm tương tự với',
#  'cậu gợi ý cà phê tương tự cho tớ với',
#  'thông tin về cà phê',
#  'xin chào gợi ý cà phê',
#  'epsro cho em hỏi cà phê được chế biến như thế nào',
#  'xin chào cậu gợi ý cà phê',
#  'chào epsro gợi ý cho em sản phẩm với',
#  'epsro cho mình hỏi cà phê giá bao nhiêu',
#  'xin chào em cà phê tương tự',
#  'cửa hàng gợi ý cà phê tương tự cho em được không',
#  'xin chào cậu cho tớ hỏi sản phẩm tương tự đi',
#  'em cho tôi hỏi công thức của cà phê là gì',
#  'cửa hàng cho tớ hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'cậu cho tớ hỏi sản phẩm tương tự với',
#  'xin chào bạn thông tin về cà phê',
#  'xin chào cho mình hỏi cà phê tương tự đi',
#  'anh gợi ý cho anh sản phẩm được không',
#  'chào bạn cho em hỏi công thức của cà phê là gì',
#  'xin chào nhân viên gợi ý cà phê tương tự cho mình được không',
#  'xin chào epsro cho tớ hỏi loại sản phẩm của cà phê là gì',
#  'epsro gợi ý cho mình sản phẩm được không',
#  'xin chào em cho em hỏi sản phẩm tương tự với',
#  'nhân viên gợi ý cho em cà phê tương tự được không',
#  'chào cho em hỏi cà phê tương tự được không',
#  'xin chào cà phê giá như thế nào',
#  'xin chào nhân viên cho anh hỏi cà phê tương tự đi',
#  'cho mình hỏi loại sản phẩm của cà phê là gì',
#  'chào gợi ý sản phẩm cho tớ với',
#  'xin chào cửa hàng cho tôi hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào epsro gợi ý cà phê tương tự cho mình đi',
#  'nhân viên cho tớ hỏi cà phê được mô tả như thế nào',
#  'em gợi ý sản phẩm cho tớ',
#  'xin chào bạn gợi ý cho mình cà phê tương tự được không',
#  'chào danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào gợi ý cà phê tương tự cho em với',
#  'em cho anh hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'chào cửa hàng cho em hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'chào cậu gợi ý cho anh sản phẩm được không',
#  'xin chào em gợi ý sản phẩm cho tôi',
#  'cậu cho mình hỏi sản phẩm tương tự với',
#  'chào epsro cho mình hỏi danh sách sản phẩm bán chạy nhất',
#  'chào epsro gợi ý cho tôi cà phê tương tự được không',
#  'chào cho tôi hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào cho anh hỏi thông tin về cà phê',
#  'chào anh gợi ý cho em cà phê tương tự được không',
#  'chào nhân viên cà phê giá bao nhiêu',
#  'chào em cho anh hỏi cà phê tương tự với',
#  'cửa hàng cho anh hỏi cà phê được mô tả như thế nào',
#  'xin chào gợi ý sản phẩm cho tôi được không',
#  'chào bạn gợi ý cho mình sản phẩm đi',
#  'xin chào cậu gợi ý cà phê tương tự cho tớ được không',
#  'anh gợi ý cho tớ sản phẩm với',
#  'chào cửa hàng cho mình hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'chào cậu cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào anh cho anh hỏi cà phê tương tự được không',
#  'chào nhân viên cho mình hỏi cà phê tương tự được không',
#  'chào epsro cho mình hỏi cà phê tương tự đi',
#  'cậu cho em hỏi cà phê còn hàng không',
#  'epsro cho tớ hỏi công thức của cà phê là gì',
#  'chào em cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'cho mình hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'chào cho anh hỏi cà phê giá bao nhiêu',
#  'chào bạn cho anh hỏi thông tin về cà phê',
#  'cho tớ hỏi sản phẩm tương tự được không',
#  'xin chào anh gợi ý cà phê tương tự cho anh được không',
#  'bạn cho em hỏi sản phẩm tương tự với',
#  'xin chào bạn gợi ý sản phẩm cho anh được không',
#  'chào bạn gợi ý cho em sản phẩm được không',
#  'cửa hàng cho anh hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào nhân viên cho tôi hỏi cà phê còn hàng không',
#  'nhân viên cho em hỏi loại sản phẩm của cà phê là gì',
#  'xin chào epsro cho tớ hỏi cà phê được chế biến như thế nào',
#  'xin chào em cho tớ hỏi sản phẩm tương tự đi',
#  'cửa hàng gợi ý sản phẩm cho mình được không',
#  'xin chào cậu gợi ý cho anh cà phê tương tự với',
#  'xin chào nhân viên cho em hỏi cà phê tương tự với',
#  'bạn gợi ý cho em cà phê tương tự với',
#  'nhân viên gợi ý sản phẩm cho anh',
#  'xin chào cho anh hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào nhân viên cho anh hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào cửa hàng cho tớ hỏi cà phê tương tự với',
#  'chào nhân viên cho anh hỏi công thức của cà phê là gì',
#  'epsro cho anh hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'cậu loại sản phẩm của cà phê là gì',
#  'xin chào epsro cho tôi hỏi cà phê tương tự đi',
#  'em cho tớ hỏi sản phẩm tương tự đi',
#  'xin chào epsro cho tớ hỏi sản phẩm tương tự với',
#  'chào bạn gợi ý cà phê tương tự cho mình với',
#  'xin chào gợi ý cà phê tương tự cho tớ đi',
#  'xin chào em cho mình hỏi cà phê còn hàng không',
#  'chào cho mình hỏi thông tin về cà phê',
#  'chào gợi ý sản phẩm cho em được không',
#  'chào nhân viên cho em hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'xin chào anh cho mình hỏi loại sản phẩm của cà phê là gì',
#  'chào epsro gợi ý cà phê tương tự cho mình với',
#  'xin chào nhân viên gợi ý cho em cà phê tương tự với',
#  'chào cậu cà phê còn hàng không',
#  'xin chào bạn gợi ý sản phẩm cho mình với',
#  'chào nhân viên gợi ý sản phẩm cho anh được không',
#  'chào nhân viên cho tớ hỏi hiện tại có thể có bao nhiêu cà phê',
#  'chào danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào em gợi ý sản phẩm cho tớ với',
#  'chào epsro gợi ý sản phẩm cho tôi',
#  'cậu gợi ý sản phẩm cho mình',
#  'chào em gợi ý cho mình sản phẩm đi',
#  'xin chào epsro gợi ý sản phẩm cho em đi',
#  'chào cửa hàng cho tôi hỏi sản phẩm tương tự đi',
#  'chào anh cho em hỏi loại sản phẩm của cà phê là gì',
#  'xin chào cửa hàng gợi ý cà phê tương tự cho tớ với',
#  'xin chào cậu gợi ý cho em cà phê tương tự được không',
#  'chào bạn cho tôi hỏi cà phê giá bao nhiêu',
#  'cửa hàng cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'cậu cho mình hỏi sản phẩm tương tự đi',
#  'xin chào anh gợi ý sản phẩm cho anh được không',
#  'chào anh cho em hỏi danh sách sản phẩm bán chạy nhất',
#  'chào cậu danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào nhân viên gợi ý sản phẩm cho anh',
#  'xin chào anh gợi ý sản phẩm cho mình đi',
#  'cửa hàng cho mình hỏi cà phê được mô tả như thế nào',
#  'xin chào nhân viên cho mình hỏi cà phê tương tự đi',
#  'em gợi ý cà phê',
#  'chào bạn cho anh hỏi sản phẩm tương tự với',
#  'xin chào bạn cho tôi hỏi cà phê tương tự được không',
#  'xin chào epsro gợi ý cà phê tương tự cho em được không',
#  'bạn cho anh hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'chào gợi ý cho anh sản phẩm với',
#  'bạn gợi ý cho anh sản phẩm được không',
#  'chào cậu cho tớ hỏi cà phê còn hàng không',
#  'xin chào cậu cho anh hỏi hiện tại có thể có bao nhiêu cà phê',
#  'nhân viên cho anh hỏi danh sách sản phẩm bán chạy nhất',
#  'epsro gợi ý cho em cà phê tương tự đi',
#  'xin chào bạn gợi ý cho anh cà phê tương tự với',
#  'chào cửa hàng cho em hỏi sản phẩm tương tự được không',
#  'epsro gợi ý cho mình sản phẩm với',
#  'chào anh gợi ý cà phê tương tự cho mình được không',
#  'xin chào cửa hàng cho tớ hỏi hiện tại có thể có bao nhiêu cà phê',
#  'chào epsro cho tôi hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào cà phê được mô tả như thế nào',
#  'chào epsro cho tôi hỏi loại sản phẩm của cà phê là gì',
#  'xin chào nhân viên gợi ý cho mình sản phẩm đi',
#  'xin chào cho tớ hỏi cà phê còn hàng không',
#  'chào epsro danh sách sản phẩm bán chạy nhất',
#  'xin chào nhân viên cho tôi hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'cửa hàng cho tớ hỏi cà phê tương tự được không',
#  'xin chào em cho em hỏi cà phê còn hàng không',
#  'chào cho em hỏi sản phẩm tương tự đi',
#  'cậu cho em hỏi sản phẩm tương tự đi',
#  'cho mình hỏi cà phê giá như thế nào',
#  'xin chào nhân viên cho tôi hỏi cà phê được chế biến như thế nào',
#  'chào em danh sách sản phẩm bán chạy nhất',
#  'xin chào cậu danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào anh gợi ý sản phẩm cho tôi được không',
#  'cho tôi hỏi cà phê giá như thế nào',
#  'nhân viên cho mình hỏi công thức của cà phê là gì',
#  'chào cậu gợi ý cho tớ sản phẩm được không',
#  'xin chào em cho em hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'chào cậu cho mình hỏi cà phê giá bao nhiêu',
#  'xin chào cửa hàng gợi ý cà phê tương tự cho em đi',
#  'chào cậu danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào cửa hàng gợi ý cà phê tương tự cho mình với',
#  'chào cho anh hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào cho anh hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'nhân viên gợi ý cho em sản phẩm đi',
#  'xin chào em cho mình hỏi cà phê tương tự được không',
#  'xin chào epsro cho tôi hỏi loại sản phẩm của cà phê là gì',
#  'xin chào em gợi ý sản phẩm cho mình đi',
#  'chào bạn cho mình hỏi cà phê giá như thế nào',
#  'chào gợi ý cho em sản phẩm đi',
#  'chào nhân viên cho tớ hỏi loại sản phẩm của cà phê là gì',
#  'xin chào cửa hàng cho em hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'bạn cho tôi hỏi cà phê tương tự với',
#  'chào anh gợi ý cà phê tương tự cho tớ đi',
#  'cậu cà phê còn hàng không',
#  'nhân viên gợi ý cho mình sản phẩm được không',
#  'xin chào epsro cho tớ hỏi sản phẩm tương tự đi',
#  'bạn cho mình hỏi cà phê giá bao nhiêu',
#  'xin chào cậu cho tớ hỏi hiện tại có thể có bao nhiêu cà phê',
#  'anh cho tớ hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'chào nhân viên cho em hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'chào cửa hàng gợi ý sản phẩm cho tôi với',
#  'chào cho tôi hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'nhân viên cho tôi hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào nhân viên gợi ý sản phẩm cho tôi được không',
#  'bạn cho mình hỏi sản phẩm tương tự với',
#  'xin chào cà phê giá bao nhiêu',
#  'xin chào epsro cho tôi hỏi cà phê được chế biến như thế nào',
#  'chào em cho em hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào em cho tôi hỏi danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'chào nhân viên gợi ý sản phẩm cho tớ đi',
#  'cậu gợi ý cho mình cà phê tương tự đi',
#  'xin chào epsro cho tôi hỏi công thức của cà phê là gì',
#  'em cho tớ hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'gợi ý cho tớ cà phê tương tự với',
#  'xin chào nhân viên cho tớ hỏi cà phê tương tự với',
#  'anh danh sách sản phẩm được mọi người mua hàng đầu',
#  'chào bạn gợi ý cho em cà phê tương tự với',
#  'chào em cho anh hỏi cà phê còn hàng không',
#  'anh cho tôi hỏi sản phẩm tương tự với',
#  'xin chào em cho anh hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'nhân viên cho anh hỏi công thức của cà phê là gì',
#  'chào anh thông tin về cà phê',
#  'chào nhân viên cho tôi hỏi cà phê được chế biến như thế nào',
#  'xin chào epsro cho mình hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'xin chào em gợi ý cà phê tương tự cho mình với',
#  'cửa hàng gợi ý cho em cà phê tương tự được không',
#  'xin chào gợi ý cà phê tương tự cho tôi đi',
#  'chào anh gợi ý sản phẩm cho anh',
#  'anh hiện tại có thể có bao nhiêu cà phê',
#  'em cho tôi hỏi loại sản phẩm của cà phê là gì',
#  'chào cho tớ hỏi thông tin về cà phê',
#  'xin chào nhân viên cà phê được chế biến như thế nào',
#  'em cho tớ hỏi cà phê giá bao nhiêu',
#  'chào anh gợi ý cà phê tương tự cho anh đi',
#  'gợi ý cho tôi cà phê tương tự với',
#  'bạn gợi ý cà phê tương tự cho tớ đi',
#  'chào cậu gợi ý cho anh sản phẩm đi',
#  'anh cho tớ hỏi cà phê được mô tả như thế nào',
#  'epsro cho tôi hỏi danh sách sản phẩm bán chạy nhất',
#  'xin chào em gợi ý sản phẩm cho em với',
#  'xin chào bạn gợi ý cà phê',
#  'xin chào nhân viên cho anh hỏi cà phê tương tự với',
#  'bạn hiện tại có thể có bao nhiêu cà phê',
#  'xin chào bạn cho tôi hỏi loại sản phẩm của cà phê là gì',
#  'chào anh cho anh hỏi cà phê được mô tả như thế nào',
#  'xin chào em cho tôi hỏi loại sản phẩm của cà phê là gì',
#  'xin chào gợi ý cà phê tương tự cho em được không',
#  'xin chào bạn cho em hỏi cà phê giá như thế nào',
#  'xin chào cậu gợi ý cà phê tương tự cho em với',
#  'chào gợi ý sản phẩm cho mình đi',
#  'em cho tớ hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào cửa hàng gợi ý cho mình cà phê tương tự đi',
#  'nhân viên gợi ý cà phê tương tự cho tôi đi',
#  'chào cà phê giá bao nhiêu',
#  'xin chào cửa hàng danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào epsro cho anh hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'xin chào epsro cho em hỏi cà phê tương tự với',
#  'xin chào cửa hàng cho tôi hỏi cà phê còn hàng không',
#  'cho em hỏi sản phẩm tương tự với',
#  'anh cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'chào cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào anh cà phê được mô tả như thế nào',
#  'gợi ý cà phê tương tự cho tớ với',
#  'epsro cho tớ hỏi loại sản phẩm của cà phê là gì',
#  'chào epsro gợi ý cho mình cà phê tương tự được không',
#  'chào cậu gợi ý sản phẩm cho tôi',
#  'epsro gợi ý sản phẩm',
#  'xin chào epsro cho anh hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'cửa hàng cho em hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'nhân viên cà phê được mô tả như thế nào',
#  'bạn cà phê giá bao nhiêu',
#  'em gợi ý cho tớ cà phê tương tự với',
#  'chào cậu gợi ý cho mình cà phê tương tự với',
#  'cửa hàng cho anh hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'xin chào cho mình hỏi hiện tại có thể có bao nhiêu cà phê',
#  'xin chào bạn gợi ý cà phê tương tự cho tôi được không',
#  'xin chào gợi ý cho tôi cà phê tương tự được không',
#  'cửa hàng cà phê được mô tả như thế nào',
#  'cửa hàng gợi ý sản phẩm cho tớ với',
#  'anh danh sách sản phẩm bán chạy hàng đầu',
#  'xin chào bạn cho anh hỏi danh sách sản phẩm được mọi người mua hàng đầu',
#  'bạn cho em hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'cậu cho tôi hỏi cà phê được chế biến như thế nào',
#  'chào epsro gợi ý sản phẩm cho tôi đi',
#  'chào nhân viên gợi ý cho em sản phẩm đi',
#  'chào nhân viên cho em hỏi cà phê được chế biến như thế nào',
#  'cậu gợi ý cà phê tương tự cho tớ đi',
#  'cà phê được chế biến như thế nào',
#  'epsro gợi ý sản phẩm cho em được không',
#  'chào cửa hàng gợi ý cho em sản phẩm được không',
#  'cậu cho mình hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào nhân viên gợi ý cho mình cà phê tương tự với',
#  'chào bạn cho tôi hỏi hiện tại có thể có bao nhiêu cà phê',
#  'chào bạn cho anh hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào cửa hàng cho tớ hỏi danh sách sản phẩm thu hút mọi người nhất',
#  'nhân viên cho mình hỏi cà phê còn hàng không',
#  'bạn cho mình hỏi danh sách sản phẩm bán chạy hàng đầu',
#  'xin chào anh cho anh hỏi cà phê được chế biến như thế nào',
#  'nhân viên cho anh hỏi sản phẩm tương tự được không',
#  'chào cậu cho mình hỏi sản phẩm tương tự với',
#  'xin chào cửa hàng danh sách sản phẩm thu hút mọi người mua nhièu nhất',
#  'xin chào anh cho tớ hỏi loại sản phẩm của cà phê là gì',
#  'cậu cho mình hỏi cà phê tương tự đi',
#  'xin chào anh gợi ý sản phẩm cho mình với',
#  'xin chào cậu gợi ý cho tớ cà phê tương tự được không',
#  'chào bạn cho em hỏi danh sách sản phẩm được mọi người mua nhiều nhất',
#  'xin chào bạn gợi ý cho em cà phê tương tự đi',
#  'chào em cho mình hỏi cà phê tương tự đi',
#  'chào anh gợi ý cà phê tương tự cho tôi với',
#  'bạn gợi ý cho mình sản phẩm với',
#  'xin chào cho anh hỏi cà phê tương tự được không',
#  'xin chào cửa hàng cho anh hỏi danh sách sản phẩm bán chạy nhất',
#  'xin chào cậu cho tôi hỏi cà phê giá như thế nào',
#  'cậu gợi ý cho tôi sản phẩm được không',
#  'xin chào bạn cho tôi hỏi cà phê được mô tả như thế nào',
#  'chào em gợi ý cho tôi cà phê tương tự với',
#  'chào epsro gợi ý cho tớ sản phẩm đi',
#  'xin chào em cho em hỏi sản phẩm tương tự đi',
#  'cửa hàng sản phẩm tương tự',
#  'xin chào anh gợi ý cà phê tương tự cho anh đi',
#  'chào anh cho tôi hỏi cà phê giá bao nhiêu',
#  'chào cà phê được mô tả như thế nào',
#  'chào cửa hàng gợi ý cà phê tương tự cho mình đi',
#  'chào bạn cho mình hỏi cà phê giá bao nhiêu',
#  'xin chào cậu cho anh hỏi cà phê được mô tả như thế nào',
#  'xin chào cậu cho em hỏi công thức của cà phê là gì',
#  'xin chào em cho em hỏi thông tin về cà phê',
#  'cậu cho mình hỏi cà phê còn hàng không',
#  'chào nhân viên gợi ý cho mình sản phẩm đi',
#  'bạn cà phê được chế biến như thế nào',
#  'anh cho em hỏi cà phê tương tự được không',
#  'xin chào cậu cho anh hỏi cà phê tương tự đi',
#  'xin chào epsro gợi ý cho tớ sản phẩm đi',
#  'cửa hàng cho tôi hỏi cà phê giá như thế nào',
#  'bạn cho tôi hỏi thông tin về cà phê',
#  'xin chào cậu cho tớ hỏi sản phẩm tương tự được không',
#  'xin chào cậu cho anh hỏi danh sách sản phẩm được mua nhiều nhấtdanh sách sản phẩm được mua hàng đầu',
#  'chào cậu cho tôi hỏi sản phẩm tương tự được không',
#  ...]

# %%
len(train_contexts)
# Out:
# 4680

# %%
train_labels = train_file.drop(columns=['Question'])

# %%
train_labels
# Out:
#       infomation  productTopSell  recommendedProduct
# 0              0               1                   0
# 1              0               1                   0
# 2              1               0                   0
# 3              1               0                   0
# 4              0               0                   1
# ...          ...             ...                 ...
# 4675           0               0                   1
# 4676           0               0                   1
# 4677           1               0                   0
# 4678           0               1                   0
# 4679           0               0                   1
#
# [4680 rows x 3 columns]

# %%
train_labels = train_labels.to_numpy()

# %%
train_labels
# Out:
# array([[0, 1, 0],
#        [0, 1, 0],
#        [1, 0, 0],
#        ...,
#        [1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
len(train_labels)
# Out:
# 4680

# %% [markdown]
# # II. Model

# %%
# !pip install tensorflow_text
# !pip install tensorflow-hub
# !pip install transformers==4.3.0
# !pip install sentencepiece
# !pip install -q underthesea
# !pip install -q sentence_transformers
# !pip install py_vncorenlp
# Out:
# Collecting tensorflow_text
#   Downloading tensorflow_text-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 15.6 MB/s eta 0:00:00
# Collecting tensorflow<2.17,>=2.16.1 (from tensorflow_text)
#   Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (0.2.0)
# Collecting h5py>=3.10.0 (from tensorflow<2.17,>=2.16.1->tensorflow_text)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 89.4 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow<2.17,>=2.16.1->tensorflow_text)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 81.1 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (1.64.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow<2.17,>=2.16.1->tensorflow_text)
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 90.7 MB/s eta 0:00:00
# Collecting keras>=3.0.0 (from tensorflow<2.17,>=2.16.1->tensorflow_text)
#   Downloading keras-3.4.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.9 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (0.37.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16.1->tensorflow_text) (1.25.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (0.43.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (13.7.1)
# Collecting namex (from keras>=3.0.0->tensorflow<2.17,>=2.16.1->tensorflow_text)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting optree (from keras>=3.0.0->tensorflow<2.17,>=2.16.1->tensorflow_text)
#   Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 32.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16.1->tensorflow_text) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16.1->tensorflow_text) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16.1->tensorflow_text) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16.1->tensorflow_text) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16.1->tensorflow_text) (0.1.2)
# Installing collected packages: namex, optree, ml-dtypes, h5py, tensorboard, keras, tensorflow, tensorflow_text
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.
# Successfully installed h5py-3.11.0 keras-3.4.0 ml-dtypes-0.3.2 namex-0.0.8 optree-0.11.0 tensorboard-2.16.2 tensorflow-2.16.1 tensorflow_text-2.16.1
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub) (1.25.2)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub) (3.20.3)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub) (2.15.1)
# Collecting tensorflow<2.16,>=2.15 (from tf-keras>=2.14.1->tensorflow-hub)
#   Downloading tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (24.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub)
#   Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 86.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.15.0)
# Collecting keras<2.16,>=2.15.0 (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub)
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 76.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.2.2)
# Installing collected packages: keras, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.0
#     Uninstalling keras-3.4.0:
#       Successfully uninstalled keras-3.4.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.16.2
#     Uninstalling tensorboard-2.16.2:
#       Successfully uninstalled tensorboard-2.16.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.16.1
#     Uninstalling tensorflow-2.16.1:
#       Successfully uninstalled tensorflow-2.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.16.1 requires tensorflow<2.17,>=2.16.1; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.15.1 which is incompatible.
# Successfully installed keras-2.15.0 tensorboard-2.15.2 tensorflow-2.15.1
# Collecting transformers==4.3.0
#   Downloading transformers-4.3.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.3.0) (3.15.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.3.0) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from transformers==4.3.0) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.3.0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.3.0) (2.31.0)
# Collecting sacremoses (from transformers==4.3.0)
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 18.9 MB/s eta 0:00:00
# Collecting tokenizers<0.11,>=0.10.1 (from transformers==4.3.0)
#   Downloading tokenizers-0.10.3.tar.gz (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.7/212.7 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.3.0) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.3.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.3.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.3.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.3.0) (2024.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.3.0) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.3.0) (1.4.2)
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 49.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 45.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.8 MB/s eta 0:00:00
# Collecting py_vncorenlp
#   Downloading py_vncorenlp-0.1.4.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyjnius (from py_vncorenlp)
#   Downloading pyjnius-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.1 MB/s eta 0:00:00
# Building wheels for collected packages: py_vncorenlp
#   Building wheel for py_vncorenlp (setup.py) ... done
#   Created wheel for py_vncorenlp: filename=py_vncorenlp-0.1.4-py3-none-any.whl size=4306 sha256=2fe2e698d83cbe815251203db58b4ee69eb0f4714c78e98a39b6625bbe08808e
#   Stored in directory: /root/.cache/pip/wheels/d5/d9/bf/62632cdb007c702a0664091e92a0bb1f18a2fcecbe962d9827
# Successfully built py_vncorenlp
# Installing collected packages: pyjnius, py_vncorenlp
# Successfully installed py_vncorenlp-0.1.4 pyjnius-1.6.1

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from transformers import AutoTokenizer, TFAutoModel
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, Dense, Dropout, Input, Lambda, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# ## Input model

# %%
bert_name = "vinai/phobert-base"

# Load the pre-trained sentence embedding model
bert = TFAutoModel.from_pretrained(bert_name)
tokenizer = AutoTokenizer.from_pretrained(bert_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/557 [00:00<?, ?B/s]
# tf_model.h5:   0%|          | 0.00/740M [00:00<?, ?B/s]
# Some layers from the model checkpoint at vinai/phobert-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at vinai/phobert-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.13M [00:00<?, ?B/s]

# %%
seq_len = [len(i.split()) for i in train_contexts]
pd.Series(seq_len).hist(bins = 30)
# Out:
# <Axes: >

# %%
MAX_LEN_CONTEXT = 23

# %%
attention_mask_context = Input(shape=(MAX_LEN_CONTEXT,), dtype=tf.int32, name='attention_mask_context')
input_ids_context = Input(shape=(MAX_LEN_CONTEXT,), dtype=tf.int32, name='input_ids_context')

# Apply the bert embedding function using a Lambda layer
embedding_context = Lambda(lambda inputs: bert(input_ids=inputs[0], attention_mask=inputs[1])[0])(
                        [input_ids_context, attention_mask_context])
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda), but
# are not present in its tracked objects:
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/pooler/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/pooler/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/word_embeddings/weight:0' shape=(64001, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/token_type_embeddings/embeddings:0' shape=(1, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/position_embeddings/embeddings:0' shape=(258, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/LayerNorm/beta:0' shape=(768,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.

# %%
embedding_context
# Out:
# <KerasTensor: shape=(None, 23, 768) dtype=float32 (created by layer 'lambda')>

# %%
# TRAIN ENCODING

train_context_encodings = tokenizer(train_contexts, truncation=True, padding='max_length', max_length=MAX_LEN_CONTEXT)

train_context_features = {key: tf.convert_to_tensor(train_context_encodings[key], dtype=tf.float32) for key in tokenizer.model_input_names}

train_context_features.keys()
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])

# %%
train_context_input_ids = train_context_features['input_ids']
train_context_attention_mask = train_context_features['attention_mask']

# %% [markdown]
# ## Label decode

# %%
def labelDecoder(number):
  if number == 2:
    return 'Recommend'
  elif number == 1:
    return 'Top sell'
  elif number == 0:
    return 'Information'
  else:
    return 'Other'

# %% [markdown]
# ## Model (CNN)

# %%
# CNN layer.
cnn_layer = tf.keras.layers.Conv1D(
    filters=100,
    kernel_size=4,
    # Use 'same' padding so outputs have the same shape as inputs.
    padding='same')

# Query encoding of shape [batch_size, Tq, filters].
context_seq_encoding = cnn_layer(embedding_context)

# Reduce over the sequence axis to produce encodings of shape
# [batch_size, filters].
context_encoding = tf.keras.layers.GlobalAveragePooling1D()(context_seq_encoding)

# Concatenate query and document encodings to produce a DNN input layer.
input_layer = tf.keras.layers.Concatenate()(
    [context_encoding])

x = Dropout(0.5)(input_layer)
out = Dense(3, activation='softmax')(x)

# %%
focal_loss = tf.keras.losses.CategoricalFocalCrossentropy(alpha=0.25, gamma=2.0)

checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
#Model
model = Model(
    inputs=[attention_mask_context, input_ids_context],
    outputs=out,
)

model.compile(optimizer=Adam(learning_rate=0.00001),
              loss=focal_loss,
              metrics=['categorical_accuracy'])

# In thông tin về kiến trúc mô hình
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids_context (InputLa  [(None, 23)]                 0         []
#  yer)
#
#  attention_mask_context (In  [(None, 23)]                 0         []
#  putLayer)
#
#  lambda (Lambda)             (None, 23, 768)              0         ['input_ids_context[0][0]',
#                                                                      'attention_mask_context[0][0]
#                                                                     ']
#
#  conv1d (Conv1D)             (None, 23, 100)              307300    ['lambda[0][0]']
#
#  global_average_pooling1d (  (None, 100)                  0         ['conv1d[0][0]']
#  GlobalAveragePooling1D)
#
#  concatenate (Concatenate)   (None, 100)                  0         ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 100)                  0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 3)                    303       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 307603 (1.17 MB)
# Trainable params: 307603 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Sequential

# %%
cnn_model = Sequential()
cnn_model.add(Conv1D(128, kernel_size=5, padding='same', input_shape=(MAX_LEN_CONTEXT, embedding_context.shape[-1])))
cnn_model.add(Conv1D(64, kernel_size=3, activation='relu'))
cnn_model.add(GlobalAveragePooling1D())
cnn_model.add(Dense(32, activation='relu'))
cnn_model.add(Dropout(0.5))
cnn_model.add(Dense(train_labels.shape[1], activation='softmax'))

# %%
# Apply Sequential model to embeddings
output = cnn_model(embedding_context)

# Define full model
model = Model(inputs=[input_ids_context, attention_mask_context], outputs=output)

# Compile model
model.compile(optimizer=Adam(learning_rate=0.00001),
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids_context (InputLa  [(None, 23)]                 0         []
#  yer)
#
#  attention_mask_context (In  [(None, 23)]                 0         []
#  putLayer)
#
#  lambda (Lambda)             (None, 23, 768)              0         ['input_ids_context[0][0]',
#                                                                      'attention_mask_context[0][0]
#                                                                     ']
#
#  sequential (Sequential)     (None, 3)                    518467    ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 518467 (1.98 MB)
# Trainable params: 518467 (1.98 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.fit([train_context_input_ids, train_context_attention_mask],
          train_labels,
          batch_size = 40,
          epochs = 10,
          validation_split=0.2,
          callbacks=[early_stopping])
# Out:
# Epoch 1/10
# 94/94 [==============================] - 44s 184ms/step - loss: 1.0228 - categorical_accuracy: 0.4722 - val_loss: 0.7921 - val_categorical_accuracy: 0.7714
# Epoch 2/10
# 94/94 [==============================] - 9s 99ms/step - loss: 0.7115 - categorical_accuracy: 0.7313 - val_loss: 0.5126 - val_categorical_accuracy: 0.9797
# Epoch 3/10
# 94/94 [==============================] - 9s 91ms/step - loss: 0.5184 - categorical_accuracy: 0.8411 - val_loss: 0.3364 - val_categorical_accuracy: 0.9989
# Epoch 4/10
# 94/94 [==============================] - 9s 97ms/step - loss: 0.3748 - categorical_accuracy: 0.9137 - val_loss: 0.2063 - val_categorical_accuracy: 1.0000
# Epoch 5/10
# 94/94 [==============================] - 9s 99ms/step - loss: 0.2863 - categorical_accuracy: 0.9356 - val_loss: 0.1334 - val_categorical_accuracy: 1.0000
# Epoch 6/10
# 94/94 [==============================] - 10s 102ms/step - loss: 0.2202 - categorical_accuracy: 0.9533 - val_loss: 0.0874 - val_categorical_accuracy: 1.0000
# Epoch 7/10
# 94/94 [==============================] - 10s 103ms/step - loss: 0.1769 - categorical_accuracy: 0.9623 - val_loss: 0.0613 - val_categorical_accuracy: 1.0000
# Epoch 8/10
# 94/94 [==============================] - 9s 101ms/step - loss: 0.1522 - categorical_accuracy: 0.9714 - val_loss: 0.0443 - val_categorical_accuracy: 1.0000
# Epoch 9/10
# 94/94 [==============================] - 9s 92ms/step - loss: 0.1325 - categorical_accuracy: 0.9730 - val_loss: 0.0326 - val_categorical_accuracy: 1.0000
# Epoch 10/10
# 94/94 [==============================] - 10s 105ms/step - loss: 0.1158 - categorical_accuracy: 0.9781 - val_loss: 0.0255 - val_categorical_accuracy: 1.0000

# %% [markdown]
# ## Predict

# %%
test_contexts = ["cà phê còn hàng không",
                 "gợi ý các cà phê tương tự với",
                 "cửa hàng gợi ý sản phẩm cho tớ được không",
                 "cho tôi các sản phẩm bán chạy nhất",
                 "danh sách sản phẩm bán chạy hàng đầu",
                 "cà phê quán này ngon không",
                 "Espresso với americano cái nào ngon hơn",
                 "cho hỏi thông tin về Espresso",
                 "Espresso còn bao nhiêu ly",
                 "Espresso giá như nào"]
test_context_encodings = tokenizer(test_contexts, truncation=True, padding='max_length', max_length=MAX_LEN_CONTEXT)

test_context_features = {key: tf.convert_to_tensor(test_context_encodings[key], dtype=tf.float32) for key in tokenizer.model_input_names}

# %%
test_context_features.keys()
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])

# %%
test_context_input_ids = test_context_features['input_ids']
test_context_attention_mask = test_context_features['attention_mask']

# %%
Test_array = model.predict([test_context_input_ids, test_context_attention_mask])
# Out:
# 1/1 [==============================] - 9s 9s/step

# %%
Test_array
# Out:
# array([[9.8838592e-01, 9.5981127e-03, 2.0160330e-03],
#        [9.9162757e-03, 4.8435203e-04, 9.8959935e-01],
#        [7.7402196e-03, 2.2299294e-03, 9.9002987e-01],
#        [2.0371737e-01, 7.2570872e-01, 7.0573911e-02],
#        [7.1149464e-03, 9.9064422e-01, 2.2408199e-03],
#        [9.2885309e-01, 5.3424099e-03, 6.5804504e-02],
#        [8.2534760e-01, 1.4400063e-01, 3.0651730e-02],
#        [8.9965498e-01, 8.8582598e-02, 1.1762467e-02],
#        [9.7039467e-01, 1.7662538e-02, 1.1942845e-02],
#        [9.7284734e-01, 2.0352717e-02, 6.7999619e-03]], dtype=float32)

# %%
y_predict = np.argmax(Test_array, axis=-1)

# %%
y_predict
# Out:
# array([0, 2, 2, 1, 1, 0, 0, 0, 0, 0])

# %%
y_predict_decoder = []

for predict in y_predict:
  y_predict_decoder.append(labelDecoder(predict))

# %%
y_predict_decoder
# Out:
# ['Information',
#  'Recommend',
#  'Recommend',
#  'Top sell',
#  'Top sell',
#  'Information',
#  'Information',
#  'Information',
#  'Information',
#  'Information']

# %% [markdown]
# ## Save model

# %%
model.save('model_coffee_question_classification.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model = load_model('model_coffee_question_classification.h5')
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda), but
# are not present in its tracked objects:
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._0/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._1/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._2/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._3/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._4/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._5/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._6/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._7/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._8/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._9/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._10/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/query/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/query/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/key/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/key/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/value/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/self/value/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/output/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/attention/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/intermediate/dense/kernel:0' shape=(768, 3072) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/intermediate/dense/bias:0' shape=(3072,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/output/dense/kernel:0' shape=(3072, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/output/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/output/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/encoder/layer_._11/output/LayerNorm/beta:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/pooler/dense/kernel:0' shape=(768, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/pooler/dense/bias:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/word_embeddings/weight:0' shape=(64001, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/token_type_embeddings/embeddings:0' shape=(1, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/position_embeddings/embeddings:0' shape=(258, 768) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/LayerNorm/gamma:0' shape=(768,) dtype=float32>
#   <tf.Variable 'tf_roberta_model/roberta/embeddings/LayerNorm/beta:0' shape=(768,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
